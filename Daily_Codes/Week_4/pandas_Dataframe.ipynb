# %%
import pandas as pd

# %%
roll = pd.Series([1, 2, 3, 4, 5])
name = pd.Series(['Sia', 'Ravi', 'Geet', 'Ajinkya', 'Avinash'])
marks = pd.Series([85, 67, 59, 40, 90])

# %%
df  = pd.DataFrame({
    'id':roll,
    'name': name,
    'marks': marks,
})

# %%
df
# Out:
#    id     name  marks
# 0   1      Sia     85
# 1   2     Ravi     67
# 2   3     Geet     59
# 3   4  Ajinkya     40
# 4   5  Avinash     90

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (5, 3)

# %%
df.columns
# Out:
# Index(['id', 'name', 'marks'], dtype='object')

# %%
"""
url -> https://mitu.co.in/dataset-> will connect to driver folder
downloads all the database starting with student*
put them in the same file folder as ur current working directory

""";

# %%
pwd
# Out:
# 'C:\\Users\\akshata'

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\akshata

# %%
import os

# %% [raw]
# print(os.getcwd())

# %%
# student.csv

# %%
df = pd.read_csv('student-info2')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df = pd.read_csv('student-info2')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
#student.tsv
